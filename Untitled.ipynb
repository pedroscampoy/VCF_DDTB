# %%
import os
import pandas as pd
import argparse



 #TODO: 
    #- better implementation of sample name
    #- exit if file don't exist
    #- create a file with the date as backup
    #- handle when sample exist
    #- create a column with coumulative samplenames

directory = "test/test"

final_ddbb = pd.read_csv("DDBB_TB_FINAL.csv", sep=',', header=0)
print("Previous final database contains %s rows and %s columns\n" % final_ddbb.shape)
print("The directory selected is: %s\nand the file is: %s" % (directory, filename))




for filename in os.listdir(directory):
    
    positions_shared = []
    positions_added = []
    
    
    
    #Manage sample name. Split by "_" and take the first word on the left
    ###################
    sample = filename.split("_")[0]
    
    print("The sample name retrieved is: %s\n" % sample)
    
    
    #Manage file[s]. Check if file exist and is greater than 0
    ###############
    file = os.path.join(directory, filename) #Whole file path
    file_info = os.stat(file) #Retrieve the file info to check if has size > 0


    if os.path.isfile(file) and file_info.st_size > 0:
        
        pass

    else:
        print("ERROR: Your file %s does not exist or is empty" % filename)

    #Import files in annotated vcf format
    #####################################

    new_sample = pd.read_csv(file, sep='\t', skiprows=[0], header=None)

    
    #Handle each new_sample
    #######################
    
    print("This file contains %s SNPs and %s columns" % new_sample.shape)
    
    
    #Check if sample exist
    ######################
    
    if sample not in final_ddbb.columns:
        print("The sample %s is NOT in final ddbb" % sample)
        print("Adding new sample %s to final ddbb" % sample)
        
        #extrac the number of columns to insert a new one
        new_colum_index = len(final_ddbb.columns)
        #final_ddbb[sample] = sample #adds a new column but fills all blanks with the value sample
        
        #add a new column with defauls values = 0
        final_ddbb.insert(new_colum_index, sample, 0)
        
        #Check if position exist
        ########################
        
        print("Checking positions(SNPs) in sample %s" % sample)
        for position in new_sample.iloc[:,0]: #extract first column in file
            if position not in final_ddbb["Position"].values:
                
                positions_added.append(position)
                
                new_row = len(final_ddbb.index)
                final_ddbb.loc[new_row,'Position'] = position
                final_ddbb.loc[new_row,'N'] = int(1)
                final_ddbb.loc[new_row,sample] = str(1)
                
            else:
                
                positions_shared.append(position)
                
                #Check whether the column matches the value and retrieve the first position [0]
                #of the object index generated
                index_position = final_ddbb.index[final_ddbb["Position"] == position][0]
                
                                              
                samples_with_position = final_ddbb.loc[index_position,'N']
                final_ddbb.loc[index_position,'N'] = samples_with_position + 1
                final_ddbb.loc[index_position,sample] = int(1)
    
    
    #Create small report with basic count
    #####################################
    
    #print("%s new positions from %s were added to final ddbb: %s" % (len(positions_added), sample, positions_added))
    #print("%s positions from %s were already in final ddbb: %s" % (len(positions_shared), sample, positions_shared))
    
    print("\nSAMPLE:\t%s\nTOTAL Variants:\t%s\nShared Variants:\t%s\nNew Variants:\t%s\n" % (sample, len(new_sample.index), len(positions_shared), len(positions_added)))
    
#Finally NaN are replaced by 0, decimals are not displayed and posiitons are sorted
final_ddbb = final_ddbb.fillna(0).astype(int).sort_values("Position")
    
print("Final database now contains %s rows and %s columns" % final_ddbb.shape)
print(final_ddbb)
# Out:
# Previous final database contains 0 rows and 2 columns
#
# The directory selected is: test/test
# and the file is: AB-40701__final.bam.snp.final
# The sample name retrieved is: AL39761
#
# This file contains 33 SNPs and 15 columns
# The sample AL39761 is NOT in final ddbb
# Adding new sample AL39761 to final ddbb
# Checking positions(SNPs) in sample AL39761
#
# SAMPLE:	AL39761
# TOTAL Variants:	33
# Shared Variants:	0
# New Variants:	33
#
# The sample name retrieved is: Lyon2
#
# This file contains 68 SNPs and 15 columns
# The sample Lyon2 is NOT in final ddbb
# Adding new sample Lyon2 to final ddbb
# Checking positions(SNPs) in sample Lyon2
#
# SAMPLE:	Lyon2
# TOTAL Variants:	68
# Shared Variants:	12
# New Variants:	56
#
# The sample name retrieved is: L-3716
#
# This file contains 31 SNPs and 15 columns
# The sample L-3716 is NOT in final ddbb
# Adding new sample L-3716 to final ddbb
# Checking positions(SNPs) in sample L-3716
#
# SAMPLE:	L-3716
# TOTAL Variants:	31
# Shared Variants:	14
# New Variants:	17
#
# The sample name retrieved is: AB-40701
#
# This file contains 14 SNPs and 15 columns
# The sample AB-40701 is NOT in final ddbb
# Adding new sample AB-40701 to final ddbb
# Checking positions(SNPs) in sample AB-40701
#
# SAMPLE:	AB-40701
# TOTAL Variants:	14
# Shared Variants:	8
# New Variants:	6
#
# Final database now contains 112 rows and 6 columns
#      Position  N  AL39761  Lyon2  L-3716  AB-40701
# 33       1849  1        0      1       0         0
# 34       2532  1        0      1       0         0
# 0        9143  1        1      0       0         0
# 35      11820  2        0      1       0         1
# 1       13460  3        1      1       1         0
# 2       14401  2        1      1       0         0
# 36      14861  2        0      1       0         1
# 37      15087  1        0      1       0         0
# 3       15117  1        1      0       0         0
# 38      16119  1        0      1       0         0
# 39      17654  1        0      1       0         0
# 40      17657  1        0      1       0         0
# 4       23174  2        1      1       0         0
# 41      25610  1        0      1       0         0
# 42      26055  1        0      1       0         0
# 89      27463  1        0      0       1         0
# 5       27469  2        1      0       1         0
# 6       29303  1        1      0       0         0
# 7       29641  1        1      0       0         0
# 8       33436  1        1      0       0         0
# 90      33457  1        0      0       1         0
# 9       33841  1        1      0       0         0
# 91      34527  1        0      0       1         0
# 43      34890  1        0      1       0         0
# 44      35608  1        0      1       0         0
# 45      36008  1        0      1       0         0
# 10      36538  2        1      1       0         0
# 46      37305  1        0      1       0         0
# 47      37334  1        0      1       0         0
# 92      37763  1        0      0       1         0
# ..        ... ..      ...    ...     ...       ...
# 99     212353  1        0      0       1         0
# 71     213147  1        0      1       0         0
# 72     222925  1        0      1       0         0
# 73     223752  1        0      1       0         0
# 74     225668  2        0      1       1         0
# 75     230170  2        0      1       0         1
# 76     233358  3        0      1       1         0
# 100    233364  1        0      0       1         0
# 77     243598  2        0      1       1         0
# 101    249522  1        0      0       1         0
# 78     251669  1        0      1       0         0
# 79     260282  1        0      1       0         0
# 80     262268  1        0      1       0         0
# 81     267751  1        0      1       0         0
# 102    274661  1        0      0       1         0
# 82     278021  1        0      1       0         0
# 83     282892  1        0      1       0         0
# 84     288260  1        0      1       0         0
# 85     296312  1        0      1       0         0
# 103    309765  1        0      0       1         0
# 86     320180  1        0      1       0         0
# 104    325505  1        0      0       1         0
# 105    327897  1        0      0       1         0
# 87     331588  1        0      1       0         0
# 88     333212  1        0      1       0         0
# 107    640954  1        0      0       0         1
# 108    676345  1        0      0       0         1
# 109    757139  1        0      0       0         1
# 110    940602  1        0      0       0         1
# 111    948294  1        0      0       0         1
#
# [112 rows x 6 columns]
